# %% [markdown]
# # Import Libraries

# %%
# import standard libraries
import numpy as np
import pandas as pd

# import plotting libraries
import matplotlib.pyplot as plt
import seaborn as sns

# modeling libraries
from sklearn.multioutput import MultiOutputRegressor
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error , mean_absolute_error

# %% [markdown]
# # DATASET

# %%
data = pd.read_csv("DATA\Results_OPT.csv")

# %%
data.head()
# Out:
#       Date       History   Date01        Sim#01   Date02         Sim#02  \
# 0  35740.0      0.000000  35740.0      0.000000  35740.0       0.000000
# 1  35741.0   4379.802246  35741.0   2189.901123  35741.0    6569.703369
# 2  35744.0  17521.486330  35744.0   8760.743165  35744.0   26282.229500
# 3  35748.0  35046.691410  35748.0  17523.345710  35748.0   52570.037120
# 4  35756.5  83436.289060  35756.5  41718.144530  35756.5  125154.433600
#
#     Date03        Sim#03   Date04        Sim#04  ...  Date.22       Sim#26  \
# 0  35740.0       0.00000  35740.0      0.000000  ...  35740.0      0.00000
# 1  35741.0   10943.13965  35741.0   4160.812134  ...  35741.0  10902.28711
# 2  35744.0   34354.37500  35744.0  16645.412010  ...  35744.0  25137.66602
# 3  35748.0  102806.74220  35748.0  33294.356840  ...  35748.0  58830.71094
# 4  35756.5  211617.06250  35756.5  79264.474610  ...  35756.5  98934.07813
#
#    Date.23        Sim#27  Date.24        Sim#28  Date.25       Sim#29  \
# ...

# %%
History = data.iloc[:,:2]
History.head()
# Out:
#       Date       History
# 0  35740.0      0.000000
# 1  35741.0   4379.802246
# 2  35744.0  17521.486330
# 3  35748.0  35046.691410
# 4  35756.5  83436.289060

# %%
Sim01 = data.iloc[:,2:4]
Sim02 = data.iloc[:,4:6]
Sim03 =data.iloc[:,6:8]
Sim04 =data.iloc[:,8:10]
Sim05 =data.iloc[:,10:12]
Sim06 =data.iloc[:,12:14]
Sim07 =data.iloc[:,14:16]
Sim08 =data.iloc[:,16:18]
Sim09 =data.iloc[:,18:20]
Sim10 =data.iloc[:,20:22]
Sim11 =data.iloc[:,22:24]
Sim12 =data.iloc[:,24:26]
Sim13 =data.iloc[:,26:28]
Sim14 =data.iloc[:,28:30]
Sim15 =data.iloc[:,30:32]
Sim16 =data.iloc[:,32:34]
Sim17 =data.iloc[:,34:36]
Sim18 =data.iloc[:,36:38]
Sim19 =data.iloc[:,38:40]
Sim20 =data.iloc[:,40:42]
Sim21 =data.iloc[:,42:44]
Sim22 =data.iloc[:,44:46]
Sim23 =data.iloc[:,46:48]
Sim24 =data.iloc[:,48:50]
Sim25 =data.iloc[:,50:52]
Sim26 =data.iloc[:,52:54]
Sim27 =data.iloc[:,54:56]
Sim28 =data.iloc[:,56:58]
Sim29 =data.iloc[:,58:60]
Sim30 =data.iloc[:,60:62]

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------------------
#                                                                         Plotting
#---------------------------------------------------------------------------------------------------------------------------------------------------------
plt.figure(figsize=(20,10), facecolor ='White')
plt.xlabel('Days'), plt.ylabel('Oil Production Total'), plt.title('Field Oil Production Total')

#plt.scatter(History.iloc[:,0],History.iloc[:,1], c='r')
plt.plot(History.iloc[:,0],History.iloc[:,1],'r--', lw=3)

plt.plot(Sim01.iloc[:,0],Sim01.iloc[:,1])
plt.plot(Sim02.iloc[:,0],Sim02.iloc[:,1])
#plt.plot(Sim03.iloc[:,0],Sim03.iloc[:,1])
plt.plot(Sim04.iloc[:,0],Sim04.iloc[:,1], lw =3)
"""
plt.plot(Sim05.iloc[:,0],Sim05.iloc[:,1])
plt.plot(Sim06.iloc[:,0],Sim06.iloc[:,1])
plt.plot(Sim07.iloc[:,0],Sim07.iloc[:,1])
plt.plot(Sim08.iloc[:,0],Sim08.iloc[:,1])
plt.plot(Sim09.iloc[:,0],Sim09.iloc[:,1])
plt.plot(Sim10.iloc[:,0],Sim10.iloc[:,1])
plt.plot(Sim11.iloc[:,0],Sim11.iloc[:,1])
plt.plot(Sim12.iloc[:,0],Sim12.iloc[:,1])
plt.plot(Sim13.iloc[:,0],Sim13.iloc[:,1])
plt.plot(Sim14.iloc[:,0],Sim14.iloc[:,1])
plt.plot(Sim15.iloc[:,0],Sim15.iloc[:,1])
plt.plot(Sim16.iloc[:,0],Sim16.iloc[:,1])
plt.plot(Sim17.iloc[:,0],Sim17.iloc[:,1])
plt.plot(Sim18.iloc[:,0],Sim18.iloc[:,1])
plt.plot(Sim19.iloc[:,0],Sim19.iloc[:,1])
plt.plot(Sim20.iloc[:,0],Sim20.iloc[:,1])
plt.plot(Sim21.iloc[:,0],Sim21.iloc[:,1])
plt.plot(Sim22.iloc[:,0],Sim22.iloc[:,1])
plt.plot(Sim23.iloc[:,0],Sim23.iloc[:,1])
plt.plot(Sim24.iloc[:,0],Sim24.iloc[:,1])
plt.plot(Sim25.iloc[:,0],Sim25.iloc[:,1])
plt.plot(Sim26.iloc[:,0],Sim26.iloc[:,1])
plt.plot(Sim27.iloc[:,0],Sim27.iloc[:,1])
plt.plot(Sim28.iloc[:,0],Sim28.iloc[:,1])
plt.plot(Sim29.iloc[:,0],Sim29.iloc[:,1])
plt.plot(Sim30.iloc[:,0],Sim30.iloc[:,1])

"""

plt.legend(['History Oil Production Total',
            'Sim_01', 'Sim_02','Sim_03','Sim_04','Sim_05','Sim_06','Sim_07','Sim_08','Sim_09','Sim_10','Sim_11','Sim_12','Sim_13',
            'Sim_14','Sim_15','Sim_16','Sim_17','Sim_18','Sim_19','Sim_20','Sim_21','Sim_22','Sim_23','Sim_24','Sim_25','Sim_26','Sim_27','Sim_28'
           ,'Sim_29','Sim_30'],loc='upper left')

# %% [markdown]
# # ML Model

# %%
y = data[['Sim#01','Sim#02','Sim#03','Sim#04','Sim#05','Sim#06','Sim#07','Sim#08','Sim#09','Sim#10','Sim#11','Sim#12','Sim#13'
         ,'Sim#14','Sim#15','Sim#16','Sim#17','Sim#18','Sim#19','Sim#20','Sim#21','Sim#22','Sim#23','Sim#24','Sim#25','Sim#26'
         ,'Sim#27','Sim#28','Sim#29','Sim#30']].values
x =data.iloc[:,0].values

x=x.reshape(946,1)

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, test_size = 0.2, random_state =42)

# %%
model = MultiOutputRegressor(XGBRegressor(random_state=0, n_estimators =200, learning_rate=0.2))

model.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-f7c6171d7ce9> in <module>
#       1 model = MultiOutputRegressor(XGBRegressor(random_state=0, n_estimators =200, learning_rate=0.2))
#       2
# ----> 3 model.fit(x_train, y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\multioutput.py in fit(self, X, y, sample_weight)
#     150         X, y = check_X_y(X, y,
#     151                          multi_output=True,
# --> 152                          accept_sparse=True)
#     153
#     154         if is_classifier(self):
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     720     if multi_output:
# ...

# %%
y_predict_1 = model.predict(x_train)
y_predict_2 = model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-141-c0f12da6136a> in <module>
# ----> 1 y_predict_1 = model.predict(x_train)
#       2 y_predict_2 = model.predict(x_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\multioutput.py in predict(self, X)
#     185             Note: Separate models are generated for each predictor.
#     186         """
# --> 187         check_is_fitted(self, 'estimators_')
#     188         if not hasattr(self.estimator, "predict"):
#     189             raise ValueError("The base estimator should implement"
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     912
#     913     if not all_or_any([hasattr(estimator, attr) for attr in attributes]):
# --> 914         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     915
#     916
#
# ...

# %%
plt.figure(figsize=(20,10), facecolor ='grey')
plt.xlabel('Days'), plt.ylabel('Oil Production Total'), plt.title('Field Oil Production Total')


plt.plot(History.iloc[:,0],History.iloc[:,1], lw =5, c='r')
plt.plot(x_train,y_predict_1,'bo')
plt.plot(x_test,y_predict_2,'go')
plt.legend(['History Oil Productin Total',
            'XGBoosting predicted oil production total (Training)',
            'XGBoosting predicted oil production total (Testing)'],loc='upper right')

# %% [markdown]
# # Best Matching

# %%
plt.figure(figsize=(20,10), facecolor ='grey')
plt.xlabel('Days'), plt.ylabel('Oil Production Total'), plt.title('Field Oil Production Total')

plt.scatter(History.iloc[:,0],History.iloc[:,1], c='r')
plt.plot(Sim04.iloc[:,0],Sim04.iloc[:,1], lw=3)
plt.legend(['Best Match (Simulation 04)','History Oil Productin Total'])
