# %% [markdown]
# # Import Libraries

# %%
# import standard libraries
import numpy as np
import pandas as pd

# import plotting libraries
import matplotlib.pyplot as plt
import seaborn as sns

# modeling libraries
from sklearn.multioutput import MultiOutputRegressor
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # DATASET

# %%
data = pd.read_csv("DATA\Results_GPR.csv")

# %%
data.head()
# Out:
#     Date      History       Date01       Sim#01       Date02       Sim#02  \
# 0  42005      0.00000  42005.00000      0.00000  42005.00000      0.00000
# 1  42006  13802.34570  42006.00000  13776.12988  42006.00000  13799.90918
# 2  42009  13274.48438  42007.82358  13317.65625  42008.45133  13299.69824
# 3  42018  12771.14160  42013.29431  12757.08105  42015.80531  12731.53613
# 4  42036  12426.12402  42020.56403  12445.01758  42025.90265  12386.15039
#
#         Date03       Sim#03  Date04       Sim#04  ...      Date.22  \
# 0  42005.00000      0.00000   42005      0.00000  ...  42005.00000
# 1  42006.00000  13773.33301   42006  13809.12109  ...  42006.00000
# 2  42008.43829  13239.20313   42009  13314.84180  ...  42008.11191
# 3  42015.75314  12696.14355   42018  12881.55371  ...  42014.44765
# 4  42025.87657  12399.63379   42036  12597.95605  ...  42025.22383
#
#         Sim#26      Date.23       Sim#27      Date.24       Sim#28  \
# 0      0.00000  42005.00000      0.00000  42005.00000      0.00000
# 1  13821.53906  42006.00000  13845.90430  42006.00000  13830.07422
# 2  13380.88379  42007.33242  13568.52539  42007.64353  13497.68848
# 3  12790.67383  42010.56688  13229.45703  42012.57411  13089.82520
# 4  12346.44727  42014.48753  12990.51367  42018.64196  12838.22852
#
#        Date.25       Sim#29      Date.26       Sim#30
# 0  42005.00000      0.00000  42005.00000      0.00000
# 1  42006.00000  13840.23535  42006.00000  13822.80957
# 2  42007.85160  13507.91602  42007.34552  13504.92480
# 3  42013.40641  13147.88574  42010.56779  13097.17871
# 4  42021.27551  12932.44922  42014.57800  12796.40332
#
# [5 rows x 62 columns]

# %%
History = data.iloc[:,:2]
History.head()
# Out:
#     Date      History
# 0  42005      0.00000
# 1  42006  13802.34570
# 2  42009  13274.48438
# 3  42018  12771.14160
# 4  42036  12426.12402

# %%
Sim01 = data.iloc[:,2:4]
Sim02 = data.iloc[:,4:6]
Sim03 =data.iloc[:,6:8]
Sim04 =data.iloc[:,8:10]
Sim05 =data.iloc[:,10:12]
Sim06 =data.iloc[:,12:14]
Sim07 =data.iloc[:,14:16]
Sim08 =data.iloc[:,16:18]
Sim09 =data.iloc[:,18:20]
Sim10 =data.iloc[:,20:22]
Sim11 =data.iloc[:,22:24]
Sim12 =data.iloc[:,24:26]
Sim13 =data.iloc[:,26:28]
Sim14 =data.iloc[:,28:30]
Sim15 =data.iloc[:,30:32]
Sim16 =data.iloc[:,32:34]
Sim17 =data.iloc[:,34:36]
Sim18 =data.iloc[:,36:38]
Sim19 =data.iloc[:,38:40]
Sim20 =data.iloc[:,40:42]
Sim21 =data.iloc[:,42:44]
Sim22 =data.iloc[:,44:46]
Sim23 =data.iloc[:,46:48]
Sim24 =data.iloc[:,48:50]
Sim25 =data.iloc[:,50:52]
Sim26 =data.iloc[:,52:54]
Sim27 =data.iloc[:,54:56]
Sim28 =data.iloc[:,56:58]
Sim29 =data.iloc[:,58:60]
Sim30 =data.iloc[:,60:62]

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------------------
#                                                                         Plotting
#---------------------------------------------------------------------------------------------------------------------------------------------------------
plt.figure(figsize=(20,10), facecolor ='grey')
plt.xlabel('Days'), plt.ylabel('Gas Production Rate'), plt.title('Field Gas Production Rate')


plt.plot(History.iloc[:,0],History.iloc[:,1],'go')

plt.plot(Sim01.iloc[:,0],Sim01.iloc[:,1])
plt.plot(Sim02.iloc[:,0],Sim02.iloc[:,1])
plt.plot(Sim03.iloc[:,0],Sim03.iloc[:,1])
plt.plot(Sim04.iloc[:,0],Sim04.iloc[:,1])
plt.plot(Sim05.iloc[:,0],Sim05.iloc[:,1])
plt.plot(Sim06.iloc[:,0],Sim06.iloc[:,1])
plt.plot(Sim07.iloc[:,0],Sim07.iloc[:,1])
plt.plot(Sim08.iloc[:,0],Sim08.iloc[:,1])
plt.plot(Sim09.iloc[:,0],Sim09.iloc[:,1])
plt.plot(Sim10.iloc[:,0],Sim10.iloc[:,1])
plt.plot(Sim11.iloc[:,0],Sim11.iloc[:,1])
plt.plot(Sim12.iloc[:,0],Sim12.iloc[:,1])
plt.plot(Sim13.iloc[:,0],Sim13.iloc[:,1])
plt.plot(Sim14.iloc[:,0],Sim14.iloc[:,1])
plt.plot(Sim15.iloc[:,0],Sim15.iloc[:,1])
plt.plot(Sim16.iloc[:,0],Sim16.iloc[:,1])
plt.plot(Sim17.iloc[:,0],Sim17.iloc[:,1])
plt.plot(Sim18.iloc[:,0],Sim18.iloc[:,1])
plt.plot(Sim19.iloc[:,0],Sim19.iloc[:,1])
plt.plot(Sim20.iloc[:,0],Sim20.iloc[:,1])
plt.plot(Sim21.iloc[:,0],Sim21.iloc[:,1])
plt.plot(Sim22.iloc[:,0],Sim22.iloc[:,1])
plt.plot(Sim23.iloc[:,0],Sim23.iloc[:,1])
plt.plot(Sim24.iloc[:,0],Sim24.iloc[:,1])
plt.plot(Sim25.iloc[:,0],Sim25.iloc[:,1])
plt.plot(Sim26.iloc[:,0],Sim26.iloc[:,1])
plt.plot(Sim27.iloc[:,0],Sim27.iloc[:,1])
plt.plot(Sim28.iloc[:,0],Sim28.iloc[:,1])
plt.plot(Sim29.iloc[:,0],Sim29.iloc[:,1])
plt.plot(Sim30.iloc[:,0],Sim30.iloc[:,1])



plt.legend(['History Gas Production Rate',
            'Sim_01', 'Sim_02','Sim_03','Sim_04','Sim_05','Sim_06','Sim_07','Sim_08','Sim_09','Sim_10','Sim_11','Sim_12','Sim_13',
            'Sim_14','Sim_15','Sim_16','Sim_17','Sim_18','Sim_19','Sim_20','Sim_21','Sim_22','Sim_23','Sim_24','Sim_25','Sim_26','Sim_27','Sim_28'
           ,'Sim_29','Sim_30'],loc='upper left')

# %% [markdown]
# # ML Model

# %%
y = data[['Sim#01','Sim#02','Sim#03','Sim#04','Sim#05','Sim#06','Sim#07','Sim#08','Sim#09','Sim#10','Sim#11','Sim#12','Sim#13'
         ,'Sim#14','Sim#15','Sim#16','Sim#17','Sim#18','Sim#19','Sim#20','Sim#21','Sim#22','Sim#23','Sim#24','Sim#25','Sim#26'
         ,'Sim#27','Sim#28','Sim#29','Sim#30']].values
x =data.iloc[:,0].values

x=x.reshape(124,1)

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, test_size = 0.2, random_state =42)

# %%
model = MultiOutputRegressor(XGBRegressor(random_state=0, n_estimators =200, learning_rate=0.1))

model.fit(x_train, y_train)
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\xgboost\core.py:444: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   "because it will generate extra copies and increase " +
# MultiOutputRegressor(estimator=XGBRegressor(base_score=None, booster=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None, gamma=None,
#                                             gpu_id=None, importance_type='gain',
#                                             interaction_constraints=None,
#                                             learning_rate=0.1,
#                                             max_delta_step=None, max_depth=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             n_estimators=200, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             objective='reg:squarederror',
#                                             random_state=0, reg_alpha=None,
#                                             reg_lambda=None,
#                                             scale_pos_weight=None,
#                                             subsample=None, tree_method=None,
#                                             validate_parameters=None,
#                                             verbosity=None),
#                      n_jobs=None)

# %%
y_predict_1 = model.predict(x_train)
y_predict_2 = model.predict(x_test)

# %%
plt.figure(figsize=(20,10), facecolor ='grey')
plt.xlabel('Days'), plt.ylabel('Gas Production Rate'), plt.title('Field Gas Production Rate')


plt.plot(History.iloc[:,0],History.iloc[:,1], lw=5, c='g')
plt.plot(x_train,y_predict_1,'bo')
plt.plot(x_test,y_predict_2,'ro')
plt.legend(['History Gas Production Rate',
            'XGBoosting predicted gas production rate (Training)',
            'XGBoosting predicted gas production rate (Testing)'],loc='upper right')

# %%
plt.figure(figsize=(20,10), facecolor ='grey')
plt.xlabel('Days'), plt.ylabel( 'Gas Production Rate'), plt.title('Field Gas Production Rate')

plt.plot(Sim04.iloc[:,0],Sim04.iloc[:,1], lw=5)
plt.scatter(History.iloc[:,0],History.iloc[:,1], c='g')

plt.legend(['Best Match (Simulation 04)', 'History Gas Production Rate'])
